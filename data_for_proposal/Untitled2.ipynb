# %%
import pandas as pd

# %% [markdown]
# source: The world bank: Agriculture & Rural Development

# %%
full_data = pd.read_csv('API_1_DS2_en_csv_v2_5873480.csv')
full_data.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  \
# 0  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 1  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 2           Rural population (% of total population)     SP.RUR.TOTL.ZS
# 3                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# 4                                   Rural population        SP.RUR.TOTL
#
#         1960          1961          1962        1963          1964  \
# 0        NaN           NaN           NaN         NaN           NaN
# 1        NaN           NaN           NaN         NaN           NaN
# 2     49.224     49.239000     49.254000     49.2700     49.285000
# 3        NaN      2.211234      1.577679      1.4226      1.245827
# ...

# %%
data = full_data[full_data['Country Name'] == 'Cambodia']

# %%
data.head()
# Out:
#      Country Name Country Code  \
# 5166     Cambodia          KHM
# 5167     Cambodia          KHM
# 5168     Cambodia          KHM
# 5169     Cambodia          KHM
# 5170     Cambodia          KHM
#
#                                          Indicator Name     Indicator Code  \
# 5166  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 5167  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 5168           Rural population (% of total population)     SP.RUR.TOTL.ZS
# 5169                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# 5170                                   Rural population        SP.RUR.TOTL
#
#              1960          1961          1962          1963          1964  \
# 5166          NaN           NaN  4.472616e+01  3.040078e+01  1.739791e+01
# 5167          NaN           NaN  1.366556e+00  1.307978e+00  1.444057e+00
# 5168       89.715  8.970700e+01  8.966700e+01  8.950300e+01  8.933800e+01
# ...

# %%
data['Indicator Name'].unique()
# Out:
# array(['Agricultural raw materials exports (% of merchandise exports)',
#        'Agricultural raw materials imports (% of merchandise imports)',
#        'Rural population (% of total population)',
#        'Rural population growth (annual %)', 'Rural population',
#        'Employment in agriculture (% of total employment) (modeled ILO estimate)',
#        'Employment in agriculture, male (% of male employment) (modeled ILO estimate)',
#        'Employment in agriculture, female (% of female employment) (modeled ILO estimate)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
#        'Agriculture, forestry, and fishing, value added (current US$)',
#        'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
#        'Rural population living in areas where elevation is below 5 meters (% of total population)',
#        'Agricultural nitrous oxide emissions (% of total)',
# ...

# %%
data.drop(['Country Name', 'Country Code', 'Indicator Code'], axis=1, inplace=True)
data.set_index('Indicator Name', inplace=True)
data.head()
# Out:
# /var/folders/x7/xqyd63rx0_s9027x7h7dktbh0000gn/T/ipykernel_2036/1986839803.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(['Country Name', 'Country Code', 'Indicator Code'], axis=1, inplace=True)
#                                                            1960          1961  \
# Indicator Name
# Agricultural raw materials exports (% of mercha...          NaN           NaN
# Agricultural raw materials imports (% of mercha...          NaN           NaN
# Rural population (% of total population)                 89.715  8.970700e+01
# Rural population growth (annual %)                          NaN  2.185955e+00
# Rural population                                    4971715.000  5.081591e+06
#
#                                                             1962  \
# Indicator Name
# ...

# %%
data = data.T
data.head()
# Out:
# Indicator Name  Agricultural raw materials exports (% of merchandise exports)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                    44.726157
# 1963                                                    30.400781
# 1964                                                    17.397906
#
# Indicator Name  Agricultural raw materials imports (% of merchandise imports)  \
# 1960                                                          NaN
# 1961                                                          NaN
# 1962                                                     1.366556
# 1963                                                     1.307978
# 1964                                                     1.444057
#
# Indicator Name  Rural population (% of total population)  \
# 1960                                              89.715
# ...

# %%
data.index
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Unnamed: 67'],
#       dtype='object')

# %%
data.loc['Unnamed: 67', :]
# Out:
# Indicator Name
# Agricultural raw materials exports (% of merchandise exports)                                NaN
# Agricultural raw materials imports (% of merchandise imports)                                NaN
# Rural population (% of total population)                                                     NaN
# Rural population growth (annual %)                                                           NaN
# Rural population                                                                             NaN
# Employment in agriculture (% of total employment) (modeled ILO estimate)                     NaN
# Employment in agriculture, male (% of male employment) (modeled ILO estimate)                NaN
# Employment in agriculture, female (% of female employment) (modeled ILO estimate)            NaN
# Agriculture, forestry, and fishing, value added (% of GDP)                                   NaN
# ...

# %%
data.drop('Unnamed: 67', axis=0, inplace=True)

# %%
data.index = pd.to_datetime(data.index, format='%Y')

# %%
data.head()
# Out:
# Indicator Name  Agricultural raw materials exports (% of merchandise exports)  \
# 1960-01-01                                                    NaN
# 1961-01-01                                                    NaN
# 1962-01-01                                              44.726157
# 1963-01-01                                              30.400781
# 1964-01-01                                              17.397906
#
# Indicator Name  Agricultural raw materials imports (% of merchandise imports)  \
# 1960-01-01                                                    NaN
# 1961-01-01                                                    NaN
# 1962-01-01                                               1.366556
# 1963-01-01                                               1.307978
# 1964-01-01                                               1.444057
#
# Indicator Name  Rural population (% of total population)  \
# 1960-01-01                                        89.715
# ...

# %%
filter_date = pd.to_datetime('2010', format='%Y')
data_gt_2010 = data[data.index >= filter_date]
data_gt_2010
# Out:
# Indicator Name  Agricultural raw materials exports (% of merchandise exports)  \
# 2010-01-01                                               2.286784
# 2011-01-01                                               3.689317
# 2012-01-01                                               3.306363
# 2013-01-01                                               3.552546
# 2014-01-01                                               3.787027
# 2015-01-01                                               2.131684
# 2016-01-01                                               2.039286
# 2017-01-01                                               2.859661
# 2018-01-01                                               2.207479
# 2019-01-01                                               1.685827
# 2020-01-01                                               1.729231
# 2021-01-01                                               2.550528
# 2022-01-01                                                    NaN
#
# ...

# %%
pd.set_option('display.max_columns', None)
data_gt_2010[data_gt_2010.index == '2022-01-01']
# Out:
# Indicator Name  Agricultural raw materials exports (% of merchandise exports)  \
# 2022-01-01                                                    NaN
#
# Indicator Name  Agricultural raw materials imports (% of merchandise imports)  \
# 2022-01-01                                                    NaN
#
# Indicator Name  Rural population (% of total population)  \
# 2022-01-01                                        74.886
#
# Indicator Name  Rural population growth (annual %)  Rural population  \
# 2022-01-01                                0.478359        12556766.0
#
# Indicator Name  Employment in agriculture (% of total employment) (modeled ILO estimate)  \
# 2022-01-01                                                    NaN
#
# Indicator Name  Employment in agriculture, male (% of male employment) (modeled ILO estimate)  \
# 2022-01-01                                                    NaN
#
# ...

# %%
data_gt_2010.drop('2022-01-01', axis=0, inplace=True)
# Out:
# /var/folders/x7/xqyd63rx0_s9027x7h7dktbh0000gn/T/ipykernel_2036/2750017439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_gt_2010.drop('2022-01-01', axis=0, inplace=True)

# %%
data_gt_2010
# Out:
# Indicator Name  Agricultural raw materials exports (% of merchandise exports)  \
# 2010-01-01                                               2.286784
# 2011-01-01                                               3.689317
# 2012-01-01                                               3.306363
# 2013-01-01                                               3.552546
# 2014-01-01                                               3.787027
# 2015-01-01                                               2.131684
# 2016-01-01                                               2.039286
# 2017-01-01                                               2.859661
# 2018-01-01                                               2.207479
# 2019-01-01                                               1.685827
# 2020-01-01                                               1.729231
# 2021-01-01                                               2.550528
#
# Indicator Name  Agricultural raw materials imports (% of merchandise imports)  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 12))

missing_value = data_gt_2010.isnull().sum() / len(data_gt_2010)
missing_value.sort_values(inplace = True)

sns.barplot(x=missing_value, y=missing_value.index)
# Out:
# <Axes: ylabel='Indicator Name'>

# %%
data_gt_2010['Employment in agriculture (% of total employment) (modeled ILO estimate)']
# Out:
# 2010-01-01    54.78567
# 2011-01-01    56.54766
# 2012-01-01    53.19247
# 2013-01-01    49.52267
# 2014-01-01    45.99603
# 2015-01-01    42.46842
# 2016-01-01    37.54026
# 2017-01-01    38.20638
# 2018-01-01    39.02749
# 2019-01-01    39.86810
# 2020-01-01    39.42049
# 2021-01-01    38.85376
# Name: Employment in agriculture (% of total employment) (modeled ILO estimate), dtype: float64

# %%
filter_columns = missing_value[missing_value > 0].index

# %%
# Drop some columns
data_gt_2010.drop(filter_columns, axis=1, inplace=True)
data_gt_2010
# Out:
# /var/folders/x7/xqyd63rx0_s9027x7h7dktbh0000gn/T/ipykernel_2036/3018044783.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_gt_2010.drop(filter_columns, axis=1, inplace=True)
# Indicator Name  Agricultural raw materials exports (% of merchandise exports)  \
# 2010-01-01                                               2.286784
# 2011-01-01                                               3.689317
# 2012-01-01                                               3.306363
# 2013-01-01                                               3.552546
# 2014-01-01                                               3.787027
# 2015-01-01                                               2.131684
# 2016-01-01                                               2.039286
# ...

# %%
sns.lineplot(data_gt_2010['Fertilizer consumption (kilograms per hectare of arable land)'])
# Out:
# <Axes: ylabel='Fertilizer consumption (kilograms per hectare of arable land)'>

# %%
sns.lineplot(data_gt_2010[['Agricultural raw materials exports (% of merchandise exports)', 'Agricultural raw materials imports (% of merchandise imports)']])
# Out:
# <Axes: >
